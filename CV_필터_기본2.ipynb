# %% [markdown]
# <a href="https://colab.research.google.com/github/yiwooil/colab/blob/main/CV_%ED%95%84%ED%84%B0_%EA%B8%B0%EB%B3%B82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c902360-315e-4fd3-a5d1-6e17895afa21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c902360-315e-4fd3-a5d1-6e17895afa21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('20141006175.jpg')
plt.imshow(img)

# %%
resize_img = cv2.resize(img, (0,0), fx=0.3, fy=0.3)
cv2_imshow(resize_img)
# Out:
# <PIL.Image.Image image mode=RGB size=576x360 at 0x7F0D697DDDD0>

# %%
gray = cv2.cvtColor(resize_img, cv2.COLOR_BGR2GRAY)
#plt.imshow(gray, cmap='gray')
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=576x360 at 0x7F0D697DDD50>

# %%
height = gray.shape[0]
width = gray.shape[1]

img_01 = np.zeros((height, width))
img_02 = np.zeros((height, width))
img_03 = np.zeros((height, width))

print(gray.shape, img_01.shape)
#plt.imshow(img_01, cmap='gray')
cv2_imshow(img_01)
# Out:
# (360, 576) (360, 576)
# <PIL.Image.Image image mode=L size=576x360 at 0x7F0D682AE890>

# %%
h_filter = [-1, 1]
v_filter = [-1, 1]
for y in range(height):
    for x in range(width):
        if y<height-1:
            if x<width-1:
                h_val = np.sum(h_filter*gray[y,x:x+2])
                img_01[y,x] = h_val
                v_val = np.sum(v_filter*gray[y:y+2,x])
                img_02[y,x] = v_val
                img_03[y,x] = np.sqrt(h_val*h_val + v_val*v_val)

# %%
#plt.imshow(img_01, cmap='gray')
cv2_imshow(img_01)
# Out:
# <PIL.Image.Image image mode=L size=576x360 at 0x7F0D7C138390>

# %%
#plt.imshow(img_02, cmap='gray')
cv2_imshow(img_02)
# Out:
# <PIL.Image.Image image mode=L size=576x360 at 0x7F0D5F02CAD0>

# %%
cv2_imshow(img_03)
# Out:
# <PIL.Image.Image image mode=L size=576x360 at 0x7F0D5F04EA90>
